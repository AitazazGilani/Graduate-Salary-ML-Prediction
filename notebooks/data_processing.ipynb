# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/NGS-81M0011-E-2018_F1.csv')
df
# Out:
#        PUMFID  VR2_080  PGM_034  PGM_P036  PGM_100  PGM_280A  PGM_280B
# 0       28111        2        1         6        2         1         2  \
# 1       28113        2        1         6        2         2         2
# 2       28114        2        1         6        2         2         2
# 3       28116        1        1         6        2         2         2
# 4       28117        1        2         3        1         2         1
# ...       ...      ...      ...       ...      ...       ...       ...
# 19559   63858        1        1         6        1         2         2
# 19560   63864        1        1         6        2         1         2
# 19561   63865        2        1         6        1         2         2
# 19562   63866        1        1         6        2         2         2
# 19563   63868        1        1         6        2         2         2
#
#        PGM_280C  PGM_280D  PGM_280E  ...  FATHEDP  FATEDGRD  FATEDINT
# ...

# %%
missing_incomes = df[df['PERSINCP'] == 99]
missing_incomes = missing_incomes[missing_incomes['JOBINCP'] != 99]
missing_incomes = missing_incomes[missing_incomes['JOBINCP'] != 96]

missing_incomes['PERSINCP'] = missing_incomes['JOBINCP']

# %%
missing_incomes
# Out:
#        PUMFID  VR2_080  PGM_034  PGM_P036  PGM_100  PGM_280A  PGM_280B
# 18      28144        2        1         6        2         2         2  \
# 63      28219        2        1         6        1         2         2
# 85      28266        2        1         6        2         2         2
# 88      28275        2        1         6        2         2         2
# 99      28301        2        1         6        2         2         2
# ...       ...      ...      ...       ...      ...       ...       ...
# 19529   63795        1        2         1        2         2         2
# 19530   63796        2        1         6        2         2         2
# 19540   63820        2        1         6        1         2         2
# 19552   63837        2        1         6        1         2         1
# 19555   63844        1        1         6        1         2         2
#
#        PGM_280C  PGM_280D  PGM_280E  ...  FATHEDP  FATEDGRD  FATEDINT
# ...

# %%
filter_df = df[df['PERSINCP'] != 99]
filter_df
# Out:
#        PUMFID  VR2_080  PGM_034  PGM_P036  PGM_100  PGM_280A  PGM_280B
# 0       28111        2        1         6        2         1         2  \
# 1       28113        2        1         6        2         2         2
# 2       28114        2        1         6        2         2         2
# 3       28116        1        1         6        2         2         2
# 4       28117        1        2         3        1         2         1
# ...       ...      ...      ...       ...      ...       ...       ...
# 19559   63858        1        1         6        1         2         2
# 19560   63864        1        1         6        2         1         2
# 19561   63865        2        1         6        1         2         2
# 19562   63866        1        1         6        2         2         2
# 19563   63868        1        1         6        2         2         2
#
#        PGM_280C  PGM_280D  PGM_280E  ...  FATHEDP  FATEDGRD  FATEDINT
# ...

# %%
updated_df = pd.concat([filter_df,missing_incomes],axis=0)
updated_df['PERSINCP'].value_counts()
# Out:
# PERSINCP
# 5     2727
# 4     2722
# 6     2213
# 3     2177
# 10    1803
# 7     1778
# 2     1669
# 1     1351
# 8     1297
# 9      868
# Name: count, dtype: int64

# %%
final_df = updated_df[['PUMFID', 'PGM_100', 'PGM_290', 'PGM_350', 'PGM_380',
       'PGM_P400', 'PGM_P405', 'EDU_010', 'EDU_020',
       'REG_INST', 'CERTLEVP', 'PGMCIPAP', 'COOP', 'HLOSGRDP', 'SCHOLAR',
       'DBTALGRD', 'PERSINCP', 'FATEDGRD', 'MOTEDGRD']]

final_df
# Out:
#        PUMFID  PGM_100  PGM_290  PGM_350  PGM_380  PGM_P400  PGM_P405
# 0       28111        2        1        2        2         1         1  \
# 1       28113        2        1        2        2         1         2
# 2       28114        2        2        1        2         2         3
# 3       28116        2        2        2        2         1         2
# 4       28117        1        2        2        2         1         1
# ...       ...      ...      ...      ...      ...       ...       ...
# 19529   63795        2        1        2        2         3         2
# 19530   63796        2        1        1        2         1         1
# 19540   63820        1        1        2        2         1         4
# 19552   63837        1        1        2        1         2         2
# 19555   63844        1        1        1        2         1         1
#
#        EDU_010  EDU_020  REG_INST  CERTLEVP  PGMCIPAP  COOP  HLOSGRDP
# ...

# %%
final_df.to_csv('../data/processed/processed_v1.csv', index=False)
